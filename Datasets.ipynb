# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthk408/store-dataset/blob/main/Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
store=pd.read_csv("/content/stores_data_set.csv")
feature=pd.read_csv("/content/Features_data_set.csv")
sale=pd.read_csv("/content/sales_data_set.csv")

# %%
store
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
sale
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
feature
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
store_sales=pd.merge(sale,store,on="Store")

# %%
store_sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
# [421570 rows x 7 columns]

# %%
feature.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %%
feature.drop(columns="IsHoliday",inplace=True)

# %%
final=pd.merge(store_sales,feature,on=["Store","Date"])

# %%
final
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# ...

# %%
final.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
# dtypes: bool(1), float64(10), int64(3), object(2)
# ...

# %%
final["Date"]=pd.to_datetime(final["Date"],format="%d/%m/%Y")

# %%
final["Year"]= final["Date"].dt.year
final["Month"]= final["Date"].dt.month
final["Day"]= final["Date"].dt.day
final["Day_of_week"] = final["Date"].dt.dayofweek
final["Week"]= final["Date"].dt.isocalendar().week

# %%
final
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1 2010-02-05      24924.50      False    A  151315
# 1           1     1 2010-02-12      46039.49       True    A  151315
# 2           1     1 2010-02-19      41595.55      False    A  151315
# 3           1     1 2010-02-26      19403.54      False    A  151315
# 4           1     1 2010-03-05      21827.90      False    A  151315
# ...       ...   ...        ...           ...        ...  ...     ...
# 421565     45    98 2012-09-28        508.37      False    B  118221
# 421566     45    98 2012-10-05        628.10      False    B  118221
# 421567     45    98 2012-10-12       1061.02      False    B  118221
# 421568     45    98 2012-10-19        760.01      False    B  118221
# 421569     45    98 2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  ...  MarkDown3  MarkDown4  \
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
#  16  Year          421570 non-null  int32
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
final["IshHoliday"]=encoder.fit_transform(final[["IsHoliday"]])
final["Type"]=encoder.fit_transform(final[["Type"]])

# %%
final.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# Year                 0
# Month                0
# Day                  0
# Day_of_week          0
# Week                 0
# IshHoliday           0
# dtype: int64

# %%
final.fillna(0,inplace=True)

# %%
final.duplicated().sum()
# Out:
# 0

# %%
final=final.drop("Date",axis=1)

# %%
final["MarkDown1"].value_counts().sum()
# Out:
# 421570

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         0 non-null       object
#  1   Dept          421570 non-null  int64
#  2   Weekly_Sales  421570 non-null  float64
#  3   IsHoliday     421570 non-null  bool
#  4   Type          421570 non-null  float64
#  5   Size          421570 non-null  int64
#  6   Temperature   421570 non-null  float64
#  7   Fuel_Price    421570 non-null  float64
#  8   MarkDown1     421570 non-null  float64
#  9   MarkDown2     421570 non-null  float64
#  10  MarkDown3     421570 non-null  float64
#  11  MarkDown4     421570 non-null  float64
#  12  MarkDown5     421570 non-null  float64
#  13  CPI           421570 non-null  float64
#  14  Unemployment  421570 non-null  float64
#  15  Year          421570 non-null  int32
#  16  Month         421570 non-null  int32
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         0 non-null       object
#  1   Dept          421570 non-null  int64
#  2   Weekly_Sales  421570 non-null  float64
#  3   IsHoliday     421570 non-null  bool
#  4   Type          421570 non-null  float64
#  5   Size          421570 non-null  int64
#  6   Temperature   421570 non-null  float64
#  7   Fuel_Price    421570 non-null  float64
#  8   MarkDown1     421570 non-null  float64
#  9   MarkDown2     421570 non-null  float64
#  10  MarkDown3     421570 non-null  float64
#  11  MarkDown4     421570 non-null  float64
#  12  MarkDown5     421570 non-null  float64
#  13  CPI           421570 non-null  float64
#  14  Unemployment  421570 non-null  float64
#  15  Year          421570 non-null  int32
#  16  Month         421570 non-null  int32
# ...

# %%
final
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday  Type    Size  Temperature  \
# 0           1     1      24924.50      False   0.0  151315        42.31
# 1           1     1      46039.49       True   0.0  151315        38.51
# 2           1     1      41595.55      False   0.0  151315        39.93
# 3           1     1      19403.54      False   0.0  151315        46.63
# 4           1     1      21827.90      False   0.0  151315        46.50
# ...       ...   ...           ...        ...   ...     ...          ...
# 421565     45    98        508.37      False   1.0  118221        64.88
# 421566     45    98        628.10      False   1.0  118221        64.89
# 421567     45    98       1061.02      False   1.0  118221        54.47
# 421568     45    98        760.01      False   1.0  118221        56.47
# 421569     45    98       1076.80      False   1.0  118221        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  ...  MarkDown4  MarkDown5  \
# ...

# %%
final.to_csv("final.csv", index=False)

from google.colab import files
files.download("final.csv")

# %%
final['Store'].isnull().sum()
# Out:
# 421570

# %%
final.corr()
# Out:
#                  Store      Dept  Weekly_Sales  IsHoliday      Type      Size  \
# Store         1.000000  0.024004     -0.085195  -0.000548  0.226410 -0.182881
# Dept          0.024004  1.000000      0.148032   0.000916  0.003708 -0.002966
# Weekly_Sales -0.085195  0.148032      1.000000   0.012774 -0.182242  0.243828
# IsHoliday    -0.000548  0.000916      0.012774   1.000000 -0.000798  0.000593
# Type          0.226410  0.003708     -0.182242  -0.000798  1.000000 -0.811593
# Size         -0.182881 -0.002966      0.243828   0.000593 -0.811593  1.000000
# Temperature  -0.050097  0.004437     -0.002312  -0.155949  0.042981 -0.058313
# Fuel_Price    0.065290  0.003572     -0.000120  -0.078281  0.029687  0.003361
# MarkDown1    -0.059844  0.001494      0.047172  -0.003521 -0.126345  0.169788
# MarkDown2    -0.033829  0.000587      0.020716   0.207604 -0.055318  0.078372
# MarkDown3    -0.020331  0.001475      0.038562   0.266471 -0.024013  0.033641
# ...

# %%
final.columns
# Out:
# Index(['Store', 'Dept', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Year', 'Month', 'Day',
#        'Day_of_week', 'Week', 'IshHoliday'],
#       dtype='object')

# %%
continues=[ 'Weekly_Sales','Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3','MarkDown4', 'MarkDown5', 'CPI','Unemployment', 'Size' ]
categories=['Store', 'Dept', 'IsHoliday','Type','Month', 'Day','Day_of_week', 'Week', 'IshHoliday','Year']

# %%
final
# Out:
#        Store  Dept  Weekly_Sales  IsHoliday  Type    Size  Temperature  \
# 0        NaN     1      24924.50      False   0.0  151315        42.31
# 1        NaN     1      46039.49       True   0.0  151315        38.51
# 2        NaN     1      41595.55      False   0.0  151315        39.93
# 3        NaN     1      19403.54      False   0.0  151315        46.63
# 4        NaN     1      21827.90      False   0.0  151315        46.50
# ...      ...   ...           ...        ...   ...     ...          ...
# 421565   NaN    98        508.37      False   1.0  118221        64.88
# 421566   NaN    98        628.10      False   1.0  118221        64.89
# 421567   NaN    98       1061.02      False   1.0  118221        54.47
# 421568   NaN    98        760.01      False   1.0  118221        56.47
# 421569   NaN    98       1076.80      False   1.0  118221        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  ...  MarkDown4  MarkDown5  \
# ...

# %%
from scipy import stats

# %%
def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(50):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.055:
      f=f+1
    else:
      t=t+1
  if t>f:
    return 1
  else:
    return 0

two_sample(final['Weekly_Sales'],final['Temperature'])
# Out:
# 0

# %%
def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(31):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.055:
      f=f+1
    else:
      t=t+1
  if t>f:
    return True
  else:
    return False

# %%
import pandas as pd
import scipy.stats as stats

# Function for categorical vs categorical (Chi-square test)
def chisquare_cat_vs_cat(d1, d2):
    return stats.chi2_contingency(pd.crosstab(d1, d2))[1] < 0.055

# Function for continuous vs continuous (T-test with bootstrapping)
def two_sample(d1, d2, num_iter=31, sample_frac=0.1):
    t, f = 0, 0  # Counters for significance
    for _ in range(num_iter):
        sample1 = d1.sample(frac=sample_frac, replace=True)
        sample2 = d2.sample(frac=sample_frac, replace=True)
        _, p_value = stats.ttest_ind(sample1, sample2, equal_var=False)  # Welch’s t-test (more robust)

        if p_value < 0.055:
            f += 1
        else:
            t += 1

    return t >= f  # Avoid bias by considering equal cases as significant

# %%
def chisqare_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False


chisqare_cat_vs_cat(df["State"],df["District"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-16790ca8b87d> in <cell line: 0>()
# ----> 1 print(d1)
#
# NameError: name 'd1' is not defined

# %%
def chi_square_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False

# %%
#defining function for categories vs categories

def annova_test(d1,d2):
  group=df_final[d2].unique()
  data={}
  for i in group:
    data[i]=df_final[d1][df_final[d2]==i]
  f_value,p_value=stats.f_oneway(*[i for i in data.values()])
  if p_value < 0.055:
    return False
  else:
    return True

df_final={}
for i in final.columns:
  final[i]={}
  for j in final.columns:
    if (i in continues) and (j in continues):
      result=two_sample(final[i],final[j])
    elif  (i in continues) and (j in categories):
      result=annova_test(i,j)
    elif (i in categories) and (j in continues):
      result=annova_test(j,i)
    elif (i in categories) and (j in categories):
      result=chi_square_cat_vs_cat(final[i],final[j])
    if result:
     df_final[i][j]=1
    else:
      df_final[i][j]=0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f038fe5e4b35> in <cell line: 0>()
#      23       result=annova_test(j,i)
#      24     elif (i in categories) and (j in categories):
# ---> 25       result=chi_square_cat_vs_cat(final[i],final[j])
#      26     if result:
#      27      df_final[i][j]=1
#
# <ipython-input-50-4704966fe7d6> in chi_square_cat_vs_cat(d1, d2)
#       1 def chi_square_cat_vs_cat(d1,d2):
# ----> 2   return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/contingency.py in chi2_contingency(observed, correction, lambda_)
#     331         raise ValueError("All values in `observed` must be nonnegative.")
#     332     if observed.size == 0:
# --> 333         raise ValueError("No data; `observed` has size 0.")
#     334
# ...

# %%
# Defining function for categories vs categories
def chisquare_cat_vs_cat(d1, d2):
    return stats.chi2_contingency(pd.crosstab(d1, d2))[1] < 0.055

# Defining function for continuous vs categorical (ANOVA test)
def anova_test(d1, d2, df):
    groups = df[d2].unique()
    data = [df[d1][df[d2] == g] for g in groups]
    f_value, p_value = stats.f_oneway(*data)
    return p_value < 0.055

# Initialize the final result matrix
df_final = pd.DataFrame(index=final.columns, columns=final.columns)

# Iterating over columns
for i in final.columns:
    for j in final.columns:
        if (i in continues) and (j in continues):
            result = two_sample(final[i], final[j])  # Ensure two_sample is defined
        elif (i in continues) and (j in categories):
            result = anova_test(i, j, final)
        elif (i in categories) and (j in continues):
            result = anova_test(j, i, final)
        elif (i in categories) and (j in categories):
            result = chisquare_cat_vs_cat(final[i], final[j])

        # Store results in dataframe
        df_final.loc[i, j] = 1 if result else 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8a08153decfc> in <cell line: 0>()
#      23             result = anova_test(j, i, final)
#      24         elif (i in categories) and (j in categories):
# ---> 25             result = chisquare_cat_vs_cat(final[i], final[j])
#      26
#      27         # Store results in dataframe
#
# <ipython-input-33-8a08153decfc> in chisquare_cat_vs_cat(d1, d2)
#       1 # Defining function for categories vs categories
#       2 def chisquare_cat_vs_cat(d1, d2):
# ----> 3     return stats.chi2_contingency(pd.crosstab(d1, d2))[1] < 0.055
#       4
#       5 # Defining function for continuous vs categorical (ANOVA test)
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/contingency.py in chi2_contingency(observed, correction, lambda_)
#     331         raise ValueError("All values in `observed` must be nonnegative.")
# ...

# %%
import pandas as pd
import scipy.stats as stats

# Function for chi-square test (category vs category)
def chi_square_cat_vs_cat(d1, d2):
    return True if stats.chi2_contingency(pd.crosstab(d1, d2))[1] < 0.05 else False

# Function for ANOVA test (numerical vs category)
def anova_test(df, d1, d2):
    groups = df[d2].unique()
    data = {i: df[d1][df[d2] == i] for i in groups}

    f_value, p_value = stats.f_oneway(*data.values())

    return p_value >= 0.05  # Return True if we fail to reject null hypothesis

# Assuming `final` is a DataFrame containing data
df_final = pd.DataFrame(index=final.columns, columns=final.columns)

for i in final.columns:
    for j in final.columns:
        if (i in continues) and (j in continues):
            result = two_sample(final[i], final[j])  # Ensure this function is defined
        elif (i in continues) and (j in categories):
            result = anova_test(final, i, j)
        elif (i in categories) and (j in continues):
            result = anova_test(final, j, i)
        elif (i in categories) and (j in categories):
            result = chi_square_cat_vs_cat(final[i], final[j])

        df_final.loc[i, j] = 1 if result else 0  # Assign to DataFrame
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-29107ab12e4c> in <cell line: 0>()
#      27             result = anova_test(final, j, i)
#      28         elif (i in categories) and (j in categories):
# ---> 29             result = chi_square_cat_vs_cat(final[i], final[j])
#      30
#      31         df_final.loc[i, j] = 1 if result else 0  # Assign to DataFrame
#
# <ipython-input-53-29107ab12e4c> in chi_square_cat_vs_cat(d1, d2)
#       4 # Function for chi-square test (category vs category)
#       5 def chi_square_cat_vs_cat(d1, d2):
# ----> 6     return True if stats.chi2_contingency(pd.crosstab(d1, d2))[1] < 0.05 else False
#       7
#       8 # Function for ANOVA test (numerical vs category)
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/contingency.py in chi2_contingency(observed, correction, lambda_)
# ...
