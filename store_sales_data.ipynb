# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthk408/store-dataset/blob/main/store_sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #File import and merge

# %%
import pandas as pd

# %%
sale=pd.read_csv("/content/sales_data_set.csv")
store=pd.read_csv("/content/stores_data_set.csv")
feature=pd.read_csv("/content/Features_data_set.csv")

# %%
store_sale=pd.merge(sale,store,on="Store")

# %%
store_sale_feature=pd.merge(store_sale,feature,on=["Store","Date","IsHoliday"])

# %%
store_sale_feature.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
ssf.to_csv("Merge.csv")

# %%
ssf=pd.read_csv("/content/Merge.csv")

# %%
ssf
# Out:
#         Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday Type  \
# 0                0      1     1  05/02/2010      24924.50      False    A
# 1                1      1     1  12/02/2010      46039.49       True    A
# 2                2      1     1  19/02/2010      41595.55      False    A
# 3                3      1     1  26/02/2010      19403.54      False    A
# 4                4      1     1  05/03/2010      21827.90      False    A
# ...            ...    ...   ...         ...           ...        ...  ...
# 421565      421565     45    98  28/09/2012        508.37      False    B
# 421566      421566     45    98  05/10/2012        628.10      False    B
# 421567      421567     45    98  12/10/2012       1061.02      False    B
# 421568      421568     45    98  19/10/2012        760.01      False    B
# 421569      421569     45    98  26/10/2012       1076.80      False    B
#
#           Size  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0       151315        42.31       2.572        NaN        NaN        NaN
# 1       151315        38.51       2.548        NaN        NaN        NaN
# 2       151315        39.93       2.514        NaN        NaN        NaN
# 3       151315        46.63       2.561        NaN        NaN        NaN
# 4       151315        46.50       2.625        NaN        NaN        NaN
# ...        ...          ...         ...        ...        ...        ...
# 421565  118221        64.88       3.997    4556.61      20.64       1.50
# 421566  118221        64.89       3.985    5046.74        NaN      18.82
# 421567  118221        54.47       4.000    1956.28        NaN       7.89
# 421568  118221        56.47       3.969    2004.02        NaN       3.18
# 421569  118221        58.85       3.882    4018.91      58.08     100.00
#
#         MarkDown4  MarkDown5         CPI  Unemployment
# 0             NaN        NaN  211.096358         8.106
# 1             NaN        NaN  211.242170         8.106
# 2             NaN        NaN  211.289143         8.106
# 3             NaN        NaN  211.319643         8.106
# 4             NaN        NaN  211.350143         8.106
# ...           ...        ...         ...           ...
# 421565    1601.01    3288.25  192.013558         8.684
# 421566    2253.43    2340.01  192.170412         8.667
# 421567     599.32    3990.54  192.327265         8.667
# 421568     437.73    1537.49  192.330854         8.667
# 421569     211.94     858.33  192.308899         8.667
#
# [421570 rows x 17 columns]

# %%
ssf.isnull().sum()
# Out:
# Unnamed: 0           0
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# dtype: int64

# %%
ssf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
# dtypes: bool(1), float64(10), int64(3), object(2)
# memory usage: 48.6+ MB

# %%
ssf.fillna(0,inplace=True)

# %%
ssf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     421570 non-null  float64
#  10  MarkDown2     421570 non-null  float64
#  11  MarkDown3     421570 non-null  float64
#  12  MarkDown4     421570 non-null  float64
#  13  MarkDown5     421570 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
# dtypes: bool(1), float64(10), int64(3), object(2)
# memory usage: 48.6+ MB

# %%
df=ssf.copy()

# %%
df
# Out:
#         Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday Type  \
# 0                0      1     1  05/02/2010      24924.50      False    A
# 1                1      1     1  12/02/2010      46039.49       True    A
# 2                2      1     1  19/02/2010      41595.55      False    A
# 3                3      1     1  26/02/2010      19403.54      False    A
# 4                4      1     1  05/03/2010      21827.90      False    A
# ...            ...    ...   ...         ...           ...        ...  ...
# 421565      421565     45    98  28/09/2012        508.37      False    B
# 421566      421566     45    98  05/10/2012        628.10      False    B
# 421567      421567     45    98  12/10/2012       1061.02      False    B
# 421568      421568     45    98  19/10/2012        760.01      False    B
# 421569      421569     45    98  26/10/2012       1076.80      False    B
#
#           Size  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0       151315        42.31       2.572       0.00       0.00       0.00
# 1       151315        38.51       2.548       0.00       0.00       0.00
# 2       151315        39.93       2.514       0.00       0.00       0.00
# 3       151315        46.63       2.561       0.00       0.00       0.00
# 4       151315        46.50       2.625       0.00       0.00       0.00
# ...        ...          ...         ...        ...        ...        ...
# 421565  118221        64.88       3.997    4556.61      20.64       1.50
# 421566  118221        64.89       3.985    5046.74       0.00      18.82
# 421567  118221        54.47       4.000    1956.28       0.00       7.89
# 421568  118221        56.47       3.969    2004.02       0.00       3.18
# 421569  118221        58.85       3.882    4018.91      58.08     100.00
#
#         MarkDown4  MarkDown5         CPI  Unemployment
# 0            0.00       0.00  211.096358         8.106
# 1            0.00       0.00  211.242170         8.106
# 2            0.00       0.00  211.289143         8.106
# 3            0.00       0.00  211.319643         8.106
# 4            0.00       0.00  211.350143         8.106
# ...           ...        ...         ...           ...
# 421565    1601.01    3288.25  192.013558         8.684
# 421566    2253.43    2340.01  192.170412         8.667
# 421567     599.32    3990.54  192.327265         8.667
# 421568     437.73    1537.49  192.330854         8.667
# 421569     211.94     858.33  192.308899         8.667
#
# [421570 rows x 17 columns]

# %%
df["Date"]=pd.to_datetime(df["Date"],format="%d/%m/%Y")

# %%
df["year"]=df["Date"].dt.year
df["month"]=df["Date"].dt.month
df["day"]=df["Date"].dt.day
df["day_of_week"]=df["Date"].dt.dayofweek
df["week"]=df["Date"].dt.isocalendar().week

# %%
df.drop("Date",axis=1,inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
df1["IsHoliday"]=encoder.fit_transform(df[["IsHoliday"]])
df1["Type"]=encoder.fit_transform(df[["Type"]])

# %%
df1.corr()
# Out:
#               Unnamed: 0     Store      Dept  Weekly_Sales  IsHoliday  \
# Unnamed: 0      1.000000  0.999198  0.045990     -0.082372  -0.000530
# Store           0.999198  1.000000  0.024004     -0.085195  -0.000548
# Dept            0.045990  0.024004  1.000000      0.148032   0.000916
# Weekly_Sales   -0.082372 -0.085195  0.148032      1.000000   0.012774
# IsHoliday      -0.000530 -0.000548  0.000916      0.012774   1.000000
# Type            0.218448  0.226410  0.003708     -0.182242  -0.000798
# Size           -0.175516 -0.182881 -0.002966      0.243828   0.000593
# Temperature    -0.053526 -0.050097  0.004437     -0.002312  -0.155949
# Fuel_Price      0.068573  0.065290  0.003572     -0.000120  -0.078281
# MarkDown1      -0.057762 -0.059844  0.001494      0.047172  -0.003521
# MarkDown2      -0.033176 -0.033829  0.000587      0.020716   0.207604
# MarkDown3      -0.019939 -0.020331  0.001475      0.038562   0.266471
# MarkDown4      -0.041262 -0.042724  0.001937      0.037467   0.011565
# MarkDown5      -0.012332 -0.012452  0.002668      0.050465  -0.015235
# CPI            -0.218301 -0.211088 -0.007477     -0.020921  -0.001944
# Unemployment    0.213702  0.208552  0.007837     -0.025864   0.010460
# year            0.003344  0.002997  0.003738     -0.010111  -0.056746
# month           0.001078  0.001011  0.000904      0.028409   0.123376
# day            -0.000019 -0.000015 -0.000678     -0.006187   0.045465
# day_of_week          NaN       NaN       NaN           NaN        NaN
# week            0.001101  0.001031  0.000882      0.027673   0.128184
#
#                   Type      Size  Temperature  Fuel_Price  MarkDown1  ...  \
# Unnamed: 0    0.218448 -0.175516    -0.053526    0.068573  -0.057762  ...
# Store         0.226410 -0.182881    -0.050097    0.065290  -0.059844  ...
# Dept          0.003708 -0.002966     0.004437    0.003572   0.001494  ...
# Weekly_Sales -0.182242  0.243828    -0.002312   -0.000120   0.047172  ...
# IsHoliday    -0.000798  0.000593    -0.155949   -0.078281  -0.003521  ...
# Type          1.000000 -0.811593     0.042981    0.029687  -0.126345  ...
# Size         -0.811593  1.000000    -0.058313    0.003361   0.169788  ...
# Temperature   0.042981 -0.058313     1.000000    0.143859  -0.026415  ...
# Fuel_Price    0.029687  0.003361     0.143859    1.000000   0.297056  ...
# MarkDown1    -0.126345  0.169788    -0.026415    0.297056   1.000000  ...
# MarkDown2    -0.055318  0.078372    -0.179672    0.029153   0.174868  ...
# MarkDown3    -0.024013  0.033641    -0.056026    0.018615  -0.014411  ...
# MarkDown4    -0.089770  0.127334    -0.050281    0.166622   0.838904  ...
# MarkDown5    -0.130125  0.153011    -0.014752    0.215420   0.415050  ...
# CPI          -0.065812 -0.003314     0.182112   -0.164210   0.010915  ...
# Unemployment  0.148720 -0.068238     0.096730   -0.033853  -0.105168  ...
# year          0.004208 -0.004975     0.065814    0.779633   0.501044  ...
# month        -0.000069 -0.001210     0.235983   -0.040876  -0.089206  ...
# day           0.000279 -0.000386     0.026832    0.028058  -0.126187  ...
# day_of_week        NaN       NaN          NaN         NaN        NaN  ...
# week         -0.000003 -0.001292     0.236276   -0.031140  -0.093572  ...
#
#               MarkDown3  MarkDown4  MarkDown5       CPI  Unemployment  \
# Unnamed: 0    -0.019939  -0.041262  -0.012332 -0.218301      0.213702
# Store         -0.020331  -0.042724  -0.012452 -0.211088      0.208552
# Dept           0.001475   0.001937   0.002668 -0.007477      0.007837
# Weekly_Sales   0.038562   0.037467   0.050465 -0.020921     -0.025864
# IsHoliday      0.266471   0.011565  -0.015235 -0.001944      0.010460
# Type          -0.024013  -0.089770  -0.130125 -0.065812      0.148720
# Size           0.033641   0.127334   0.153011 -0.003314     -0.068238
# Temperature   -0.056026  -0.050281  -0.014752  0.182112      0.096730
# Fuel_Price     0.018615   0.166622   0.215420 -0.164210     -0.033853
# MarkDown1     -0.014411   0.838904   0.415050  0.010915     -0.105168
# MarkDown2     -0.006080   0.113250   0.131735 -0.003554     -0.041427
# MarkDown3      1.000000  -0.012020   0.042471 -0.005839     -0.018078
# MarkDown4     -0.012020   1.000000   0.303370 -0.002047     -0.076513
# MarkDown5      0.042471   0.303370   1.000000  0.067906     -0.120406
# CPI           -0.005839  -0.002047   0.067906  1.000000     -0.299953
# Unemployment  -0.018078  -0.076513  -0.120406 -0.299953      1.000000
# year           0.006789   0.335340   0.402964  0.074544     -0.237161
# month          0.116031  -0.105569   0.055770  0.005282     -0.012444
# day            0.072156  -0.152753  -0.055893  0.002744     -0.003793
# day_of_week         NaN        NaN        NaN       NaN           NaN
# week           0.122323  -0.114168   0.055737  0.006342     -0.015490
#
#                   year     month       day  day_of_week      week
# Unnamed: 0    0.003344  0.001078 -0.000019          NaN  0.001101
# Store         0.002997  0.001011 -0.000015          NaN  0.001031
# Dept          0.003738  0.000904 -0.000678          NaN  0.000882
# Weekly_Sales -0.010111  0.028409 -0.006187          NaN  0.027673
# IsHoliday    -0.056746  0.123376  0.045465          NaN  0.128184
# Type          0.004208 -0.000069  0.000279          NaN -0.000003
# Size         -0.004975 -0.001210 -0.000386          NaN -0.001292
# Temperature   0.065814  0.235983  0.026832          NaN  0.236276
# Fuel_Price    0.779633 -0.040876  0.028058          NaN -0.031140
# MarkDown1     0.501044 -0.089206 -0.126187          NaN -0.093572
# MarkDown2     0.131867 -0.019360  0.051971          NaN -0.012812
# MarkDown3     0.006789  0.116031  0.072156          NaN  0.122323
# MarkDown4     0.335340 -0.105569 -0.152753          NaN -0.114168
# MarkDown5     0.402964  0.055770 -0.055893          NaN  0.055737
# CPI           0.074544  0.005282  0.002744          NaN  0.006342
# Unemployment -0.237161 -0.012444 -0.003793          NaN -0.015490
# year          1.000000 -0.194288  0.005835          NaN -0.181797
# month        -0.194288  1.000000  0.016363          NaN  0.995999
# day           0.005835  0.016363  1.000000          NaN  0.104719
# day_of_week        NaN       NaN       NaN          NaN       NaN
# week         -0.181797  0.995999  0.104719          NaN  1.000000
#
# [21 rows x 21 columns]

# %%
continues=['Weekly_Sales','Temperature','Size','Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3','MarkDown4', 'MarkDown5', 'CPI', 'Unemployment','year']
categories=['Store', 'Dept','IsHoliday', 'Type','month', 'day','day_of_week', 'week']

# %%
from scipy import stats

def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(31):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.055:
      f=f+1
    else:
      t=t+1
  if t>f:
    return True
  else:
    return False

#defining function for categories vs categories
def chisqare_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False

def annova_test(d1,d2):
  group=df[d2].unique()
  data={}
  for i in group:
    data[i]=df[d1][df[d2]==i]
  f_value,p_value=stats.f_oneway(*[i for i in data.values()])
  if p_value < 0.055:
    return False
  else:
    return True

final={}
for i in df.columns:
  final[i]={}
  for j in df.columns:
    if (i in continues) and (j in continues):
      result=two_sample(df[i],df[j])
    elif  (i in continues) and (j in categories):
      result=annova_test(i,j)
    elif (i in categories) and (j in continues):
      result=annova_test(j,i)
    elif (i in categories) and (j in categories):
      result=chisqare_cat_vs_cat(df[i],df[j])
    if result:
      final[i][j]=1
    else:
      final[i][j]=0
# Out:
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:531: ConstantInputWarning: Each of the input arrays is constant; the F statistic is not defined or infinite
#   res = hypotest_fun_out(*samples, **kwds)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-b94df291a585> in <cell line: 0>()
#      39       result=two_sample(df[i],df[j])
#      40     elif  (i in continues) and (j in categories):
# ---> 41       result=annova_test(i,j)
#      42     elif (i in categories) and (j in continues):
#      43       result=annova_test(j,i)
#
# <ipython-input-52-b94df291a585> in annova_test(d1, d2)
#      26   for i in group:
#      27     data[i]=df[d1][df[d2]==i]
# ---> 28   f_value,p_value=stats.f_oneway(*[i for i in data.values()])
#      29   if p_value < 0.055:
#      30     return False
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py in axis_nan_policy_wrapper(***failed resolving arguments***)
#     529                 if sentinel:
#     530                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531                 res = hypotest_fun_out(*samples, **kwds)
#     532                 res = result_to_tuple(res)
#     533                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_stats_py.py in f_oneway(axis, *samples)
#    4086     """
#    4087     if len(samples) < 2:
# -> 4088         raise TypeError('at least two inputs are required;'
#    4089                         f' got {len(samples)}.')
#    4090
#
# TypeError: at least two inputs are required; got 1.

# %%
import seaborn as sns

# %%
df=pd.DataFrame(final)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from scipy.stats import kurtosis
from scipy.stats import norm

# %%
for i in df.columns:                                   #skew -0.5 to 0.5 and kurtosis -3 to 3
  print(i,kurtosis(df[i]),df[i].skew())
# Out:
# Unnamed: 0 nan 0.0
# Store nan 0.0
# Dept nan 0.0
# Weekly_Sales nan 0.0
# IsHoliday nan 0.0
# Type nan 0.0
# Size nan 0.0
# Temperature nan 0.0
# Fuel_Price nan 0.0
# MarkDown1 nan 0.0
# MarkDown2 nan 0.0
# MarkDown3 nan 0.0
# MarkDown4 nan 0.0
# MarkDown5 nan 0.0
# CPI nan 0.0
# Unemployment nan 0.0
# year nan 0.0
# month nan 0.0
# day nan 0.0
# day_of_week nan 0.0
# week nan 0.0

# %%
for i in continues:
  print(i,kurtosis(df[i]),df[i].skew())
# Out:
# Weekly_Sales nan 0.0
# Temperature nan 0.0
# Size nan 0.0
# Fuel_Price nan 0.0
# MarkDown1 nan 0.0
# MarkDown2 nan 0.0
# MarkDown3 nan 0.0
# MarkDown4 nan 0.0
# MarkDown5 nan 0.0
# CPI nan 0.0
# Unemployment nan 0.0
# year nan 0.0

# %%
ssf[ssf[i]==0]
# Out:
# Empty DataFrame
# Columns: [Store, Dept, Date, Weekly_Sales, IsHoliday, Type, Size, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment]
# Index: []

# %%
continues
# Out:
# ['Weekly_Sales',
#  'Size',
#  'Temperature',
#  'Fuel_Price',
#  'MarkDown1',
#  'MarkDown2',
#  'MarkDown3',
#  'MarkDown4',
#  'MarkDown5',
#  'CPI',
#  'Unemployment']

# %%
df.drop(df.loc[df["km"]==0].index,inplace=True)

# %%
ssf.drop(ssf.loc[ssf["Weekly_Sales"]==0].index,inplace=True)

# %%
ssf[ssf["Weekly_Sales"]==0].drop("Weekly_Sales",axis=1)
# Out:
# Empty DataFrame
# Columns: [Store, Dept, Date, IsHoliday, Type, Size, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment]
# Index: []

# %%
data=['Weekly_Sales', 'Size','Temperature','Fuel_Price','CPI', 'Unemployment']             #kurtosis   -3 to 3
from scipy import stats         #skew       -1 to 1
method=[0,0.5,-0.5,1,-1,2,-2]
for i in method:
  for j in data:
    print(i,j)
    print("-----------------------------------")
    print("skewness",pd.DataFrame(stats.boxcox(df[j],lmbda=i)).skew().values,"kurtosis",pd.DataFrame(stats.boxcox(df[j],lmbda=i)).kurtosis().values)
# Out:
# 0 Weekly_Sales
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 0 Size
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 0 Temperature
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 0 Fuel_Price
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 0 CPI
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 0 Unemployment
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 0.5 Weekly_Sales
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 0.5 Size
# -----------------------------------
# skewness [2.12305987] kurtosis [2.77585544]
# 0.5 Temperature
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 0.5 Fuel_Price
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 0.5 CPI
# -----------------------------------
# skewness [2.88793907] kurtosis [7.03703704]
# 0.5 Unemployment
# -----------------------------------
# skewness [1.2505143] kurtosis [-0.49673203]
# -0.5 Weekly_Sales
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -0.5 Size
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -0.5 Temperature
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -0.5 Fuel_Price
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -0.5 CPI
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -0.5 Unemployment
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 1 Weekly_Sales
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 1 Size
# -----------------------------------
# skewness [2.12305987] kurtosis [2.77585544]
# 1 Temperature
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 1 Fuel_Price
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 1 CPI
# -----------------------------------
# skewness [2.88793907] kurtosis [7.03703704]
# 1 Unemployment
# -----------------------------------
# skewness [1.2505143] kurtosis [-0.49673203]
# -1 Weekly_Sales
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -1 Size
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -1 Temperature
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -1 Fuel_Price
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -1 CPI
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -1 Unemployment
# -----------------------------------
# skewness [nan] kurtosis [nan]
# 2 Weekly_Sales
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 2 Size
# -----------------------------------
# skewness [2.12305987] kurtosis [2.77585544]
# 2 Temperature
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 2 Fuel_Price
# -----------------------------------
# skewness [4.47213595] kurtosis [20.]
# 2 CPI
# -----------------------------------
# skewness [2.88793907] kurtosis [7.03703704]
# 2 Unemployment
# -----------------------------------
# skewness [1.2505143] kurtosis [-0.49673203]
# -2 Weekly_Sales
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -2 Size
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -2 Temperature
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -2 Fuel_Price
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -2 CPI
# -----------------------------------
# skewness [nan] kurtosis [nan]
# -2 Unemployment
# -----------------------------------
# skewness [nan] kurtosis [nan]
